# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from __future__ import division
import scipy.stats as stats
import seaborn as sns

# %%
def rng(m=2**32, a=1103515245, c=12345):
    rng.current = (a*rng.current + c) % m
    return rng.current/m

# %%
rng.current = 1

# %%
[rng() for i in range(10)]
# Out:
# [0.25693503906950355,
#  0.5878706516232342,
#  0.15432575810700655,
#  0.767266943352297,
#  0.9738139626570046,
#  0.5858681506942958,
#  0.8511155843734741,
#  0.6132153405342251,
#  0.7473867232911289,
#  0.06236015981994569]

# %%
import numpy.random as npr

rs = npr.normal(loc=0.5, scale=0.5, size=1000)
plt.hist(rs, bins=20, histtype='step', normed=True, linewidth=1)
plt.show()

# %%
import scipy.stats as ss

n = 5
xs = [0.1, 0.5, 0.9]
rv = ss.norm(loc=0.5, scale=0.5)

print(rv.pdf(xs)) # equivalent of dbeta
print(rv.cdf(xs)) # equivalent of pbeta
print(rv.ppf(xs)) # equvialent of qbeta
print(rv.rvs(n)) # equivalent of rbeta
xs = np.linspace(0, 1, 100)
plt.plot(xs, ss.norm.pdf(xs, loc=0.5, scale=0.5));
plt.show()
# Out:
# [ 0.57938311  0.79788456  0.57938311]
# [ 0.2118554  0.5        0.7881446]
# [-0.14077578  0.5         1.14077578]
# [ 0.07142826  0.36331963  0.75677573  0.33714121  0.92719391]
